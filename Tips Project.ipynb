# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
a=sns.load_dataset("tips")

# %%
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
b=a[['total_bill','tip','sex','smoker']]
sns.scatterplot(data=b)
# Out:
# <Axes: >

# %%
pd.isnull(a).sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.scatterplot(data=a,x='tip',y='total_bill',hue='sex',style='smoker')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.kdeplot(data=a)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(data=a,x='total_bill',bins=10)
sns.histplot(data=a,x='tip',bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax=sns.countplot(x='sex',data=a)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize=(6,3))
ax=sns.countplot(x='smoker',data=a)
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# <BarContainer object of 2 artists>

# %%
# Out:
# [<BarContainer object of 2 artists>]

# %% [markdown]
# # Tip

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['sex'],as_index=False)['tip'].sum().sort_values(by='tip',ascending=False)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='sex',y='tip')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['smoker'],as_index=False)['tip'].sum().sort_values(by='tip',ascending=False)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='smoker',y='tip')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['day'],as_index=False)['tip'].sum().sort_values(by='tip',ascending=False)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='day',y='tip')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['time'],as_index=False)['tip'].sum().sort_values(by='tip',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='time',y='tip')
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %% [markdown]
# # Total_Bill

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['time'],as_index=False)['total_bill'].sum().sort_values(by='total_bill',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='time',y='total_bill')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['day'],as_index=False)['total_bill'].sum().sort_values(by='total_bill',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['sex'],as_index=False)['total_bill'].sum().sort_values(by='total_bill',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='sex',y='total_bill')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
plt.figure(figsize=(6,3))
a1=a.groupby(['smoker'],as_index=False)['total_bill'].sum().sort_values(by='total_bill',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='smoker',y='total_bill')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
plt.figure(figsize=(6,3))
a1=df.groupby(['day'],as_index=False)['sex'].count().sort_values(by='sex',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=a1,x='day',y='sex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19736\838455343.py in <module>
#       1 plt.figure(figsize=(6,3))
# ----> 2 a1=df.groupby(['day'],as_index=False)['sex'].count().sort_values(by='sex',ascending=False).head(10)
#       3 sns.set(rc={'figure.figsize':(15,5)})
#       4 sns.barplot(data=a1,x='day',y='sex')
#
# NameError: name 'df' is not defined

# %%
a

# %%
df=a[a['sex']=='Male']
df

# %%
pivot_table = a.pivot_table(values='total_bill', index='sex', columns='smoker')
print(pivot_table)
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='.2f', cbar_kws={'label': 'Total Bill'})
plt.title('Heatmap of Total Bill by Sex and Smoker')
plt.show()
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
plt.figure(figsize=(6, 3))
ax = sns.countplot(x='day', hue='sex', data=a)
for container in ax.containers:
    ax.bar_label(container, fontsize=10)
plt.title('Count of Males and Females per Day')
plt.xlabel('Day of the Week')
plt.ylabel('Count of Customers')
plt.legend(title='Sex', loc='upper left', ncol=2)
plt.show()

# %%
plt.figure(figsize=(6, 3))
ax = sns.countplot(x='day', hue='smoker', data=a)
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12)
plt.title('Count of Smokers and Non-Smokers per Day')
plt.xlabel('Day of the Week')
plt.ylabel('Count of Customers')
plt.legend(title='Smoker', loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.show()

# %%
plt.figure(figsize=(6, 3))
ax = sns.countplot(x='day', hue='time', data=a)
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12)
plt.title('Count of Smokers and Non-Smokers per Day')
plt.xlabel('Day of the Week')
plt.ylabel('Count of Customers')
plt.legend(title='Meal', loc='upper right', bbox_to_anchor=(0.5, 1.05), ncol=2)
plt.show()

# %%
a

# %%
tips = sns.load_dataset('tips')
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(tips['total_bill'], kde=True, color='blue', bins=20)  # kde=True adds a kernel density estimate
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
sns.lineplot(x='total_bill', y='tip', data=tips, color='green')
plt.title('Line Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.tight_layout()
plt.show()

# %%
gender_smoker_count = a.groupby(['sex', 'smoker']).size().unstack(fill_value=0)#When unstack_fill_value=0 is specified, any missing values (NaN) that result from unstacking the data will be replaced with 0.
plt.figure(figsize=(8, 6))
plt.subplot(1, 2, 1)
gender_smoker_count.loc['Male'].plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen'])#startangle=This will display the percentage(number) in 90 degree
plt.title('Smoker vs Non-Smoker for Male')
plt.subplot(1, 2, 2)
gender_smoker_count.loc['Female'].plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen'])
plt.title('Smoker vs Non-Smoker for Female')
plt.tight_layout() #Used to prevent the overlapping
plt.show()

# %%
print(gender_smoker_count )
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assume dataset 'a' is already loaded

# Find highest and lowest total bill by sex
max_bill_sex = a.groupby("sex")["total_bill"].max()
min_bill_sex = a.groupby("sex")["total_bill"].min()
max_tip_sex = a.groupby("sex")["tip"].max()  
min_tip_sex = a.groupby("sex")["tip"].min()  

# Find highest and lowest total bill & tip by smoker
max_bill_smoker = a.groupby("smoker")[["total_bill", "tip"]].max()
min_bill_smoker = a.groupby("smoker")[["total_bill", "tip"]].min()

fig, axes = plt.subplots(4, 2, figsize=(12, 16))

# --- Row 1: Total Bill by Gender ---
sns.barplot(ax=axes[0, 0], x=max_bill_sex.index, y=max_bill_sex.values, palette="coolwarm") #we are passing index in the x and values in the y of max_bill_sex
axes[0, 0].set_xlabel("Gender")
axes[0, 0].set_ylabel("Highest Total Bill")
axes[0, 0].set_title("Highest Total Bill by Gender")
for container in axes[0, 0].containers:
    axes[0, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

sns.barplot(ax=axes[0, 1], x=min_bill_sex.index, y=min_bill_sex.values, palette="dark:#1B60D8")
axes[0, 1].set_xlabel("Gender")
axes[0, 1].set_ylabel("Lowest Total Bill")
axes[0, 1].set_title("Lowest Total Bill by Gender")
for container in axes[0, 1].containers:
    axes[0, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Row 2: Total Bill by Smoker ---
sns.barplot(ax=axes[1, 0], x=max_bill_smoker.index, y=max_bill_smoker["total_bill"], palette="coolwarm")
axes[1, 0].set_xlabel("Smoker")
axes[1, 0].set_ylabel("Highest Total Bill")
axes[1, 0].set_title("Highest Total Bill by Smoker")
for container in axes[1, 0].containers:
    axes[1, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3) #padding is used to add the space between two plot,axes,title

sns.barplot(ax=axes[1, 1], x=min_bill_smoker.index, y=min_bill_smoker["total_bill"], palette="dark:#1B60D8")
axes[1, 1].set_xlabel("Smoker")
axes[1, 1].set_ylabel("Lowest Total Bill")
axes[1, 1].set_title("Lowest Total Bill by Smoker")
for container in axes[1, 1].containers:
    axes[1, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Row 3: Tips by Smoker ---
sns.barplot(ax=axes[2, 0], x=max_bill_smoker.index, y=max_bill_smoker["tip"], palette="coolwarm")
axes[2, 0].set_xlabel("Smoker")
axes[2, 0].set_ylabel("Highest Tip")
axes[2, 0].set_title("Highest Tip by Smoker")
for container in axes[2, 0].containers:
    axes[2, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

sns.barplot(ax=axes[2, 1], x=min_bill_smoker.index, y=min_bill_smoker["tip"], palette="dark:#1B60D8")
axes[2, 1].set_xlabel("Smoker")
axes[2, 1].set_ylabel("Lowest Tip")
axes[2, 1].set_title("Lowest Tip by Smoker")
for container in axes[2, 1].containers:
    axes[2, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Row 4: Tips by Gender ---
sns.barplot(ax=axes[3, 0], x=max_tip_sex.index, y=max_tip_sex.values, palette="coolwarm")
axes[3, 0].set_xlabel("Gender")
axes[3, 0].set_ylabel("Highest Tip")
axes[3, 0].set_title("Highest Tip by Gender")
for container in axes[3, 0].containers:
    axes[3, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

sns.barplot(ax=axes[3, 1], x=min_tip_sex.index, y=min_tip_sex.values, palette="dark:#1B60D8")
axes[3, 1].set_xlabel("Gender")
axes[3, 1].set_ylabel("Lowest Tip")
axes[3, 1].set_title("Lowest Tip by Gender")
for container in axes[3, 1].containers:
    axes[3, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# Add text below each graph
labels = [
    f"Highest Total Bills:\n{max_bill_sex.to_string()}",
    f"Lowest Total Bills:\n{min_bill_sex.to_string()}",
    f"Highest Total Bills (Smoker):\n{max_bill_smoker['total_bill'].to_string()}",
    f"Lowest Total Bills (Smoker):\n{min_bill_smoker['total_bill'].to_string()}",
    f"Highest Tips (Smoker):\n{max_bill_smoker['tip'].to_string()}",
    f"Lowest Tips (Smoker):\n{min_bill_smoker['tip'].to_string()}",
    f"Highest Tips (Gender):\n{max_tip_sex.to_string()}",
    f"Lowest Tips (Gender):\n{min_tip_sex.to_string()}"
]

for i, ax in enumerate(axes.flat):
    ax.text(0.5, -0.35, labels[i], fontsize=10, ha="center", va="top", transform=ax.transAxes, bbox=dict(facecolor="lightgray", edgecolor="black", boxstyle="round,pad=0.3"))
#transfor=it is used to positioning inside a subplot
#ha=horizontal alignment
#va=vertical alignment
#bbox=is an parameter which is used to create background box around the text
plt.tight_layout()
plt.show()

# %%
print(labels)
# Out:
# ['Highest Total Bills:\nsex\nMale      50.81\nFemale    44.30', 'Lowest Total Bills:\nsex\nMale      7.25\nFemale    3.07', 'Highest Total Bills (Smoker):\nsmoker\nYes    50.81\nNo     48.33', 'Lowest Total Bills (Smoker):\nsmoker\nYes    3.07\nNo     7.25', 'Highest Tips (Smoker):\nsmoker\nYes    10.0\nNo      9.0', 'Lowest Tips (Smoker):\nsmoker\nYes    1.0\nNo     1.0', 'Highest Tips (Gender):\nsex\nMale      10.0\nFemale     6.5', 'Lowest Tips (Gender):\nsex\nMale      1.0\nFemale    1.0']

# %%
print(max_bill_sex)
# Out:
# sex
# Male      50.81
# Female    44.30
# Name: total_bill, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter data for smokers and non-smokers
non_smokers = a[a["smoker"] == "No"]
smokers = a[a["smoker"] == "Yes"]

# Find highest and lowest total bill by gender for non-smokers
max_bill_nonsmoker = non_smokers.groupby("sex")["total_bill"].max()
min_bill_nonsmoker = non_smokers.groupby("sex")["total_bill"].min()

# Find highest and lowest tip by gender for smokers and non-smokers
max_tip_nonsmoker = non_smokers.groupby("sex")["tip"].max()
min_tip_nonsmoker = non_smokers.groupby("sex")["tip"].min()
max_tip_smoker = smokers.groupby("sex")["tip"].max()
min_tip_smoker = smokers.groupby("sex")["tip"].min()

# Create figure with 2 rows and 2 columns (4 graphs)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# --- Highest Tip by Non-Smoking Gender ---
sns.barplot(ax=axes[0, 0], x=max_tip_nonsmoker.index, y=max_tip_nonsmoker.values, palette="coolwarm")
axes[0, 0].set_xlabel("Gender (Non-Smoker)")
axes[0, 0].set_ylabel("Highest Tip")
axes[0, 0].set_title("Highest Tip by Non-Smoking Gender")
for container in axes[0, 0].containers:
    axes[0, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Lowest Tip by Non-Smoking Gender ---
sns.barplot(ax=axes[0, 1], x=min_tip_nonsmoker.index, y=min_tip_nonsmoker.values, palette="dark:#1B60D8")
axes[0, 1].set_xlabel("Gender (Non-Smoker)")
axes[0, 1].set_ylabel("Lowest Tip")
axes[0, 1].set_title("Lowest Tip by Non-Smoking Gender")
for container in axes[0, 1].containers:
    axes[0, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Highest Tip by Smoking Gender ---
sns.barplot(ax=axes[1, 0], x=max_tip_smoker.index, y=max_tip_smoker.values, palette="coolwarm")
axes[1, 0].set_xlabel("Gender (Smoker)")
axes[1, 0].set_ylabel("Highest Tip")
axes[1, 0].set_title("Highest Tip by Smoking Gender")
for container in axes[1, 0].containers:
    axes[1, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Lowest Tip by Smoking Gender ---
sns.barplot(ax=axes[1, 1], x=min_tip_smoker.index, y=min_tip_smoker.values, palette="dark:#1B60D8")
axes[1, 1].set_xlabel("Gender (Smoker)")
axes[1, 1].set_ylabel("Lowest Tip")
axes[1, 1].set_title("Lowest Tip by Smoking Gender")
for container in axes[1, 1].containers:
    axes[1, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# Add text below each graph
labels = [
    f"Highest Tips (Non-Smoker):\n{max_tip_nonsmoker.to_string()}",
    f"Lowest Tips (Non-Smoker):\n{min_tip_nonsmoker.to_string()}",
    f"Highest Tips (Smoker):\n{max_tip_smoker.to_string()}",
    f"Lowest Tips (Smoker):\n{min_tip_smoker.to_string()}"
]

for i, ax in enumerate(axes.flat):
    ax.text(0.5, -0.25, labels[i], fontsize=10, ha="center", va="top", transform=ax.transAxes, 
            bbox=dict(facecolor="lightgray", edgecolor="black", boxstyle="round,pad=0.3"))

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter data for smokers and non-smokers
non_smokers = a[a["smoker"] == "No"]
smokers = a[a["smoker"] == "Yes"]

# Find highest and lowest total bill by gender for smokers and non-smokers
max_bill_nonsmoker = non_smokers.groupby("sex")["total_bill"].max()
min_bill_nonsmoker = non_smokers.groupby("sex")["total_bill"].min()
max_bill_smoker = smokers.groupby("sex")["total_bill"].max()
min_bill_smoker = smokers.groupby("sex")["total_bill"].min()

# Create figure with 2 rows and 2 columns (4 graphs)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# --- Highest Total Bill by Non-Smoking Gender ---
sns.barplot(ax=axes[0, 0], x=max_bill_nonsmoker.index, y=max_bill_nonsmoker.values, palette="coolwarm")
axes[0, 0].set_xlabel("Gender (Non-Smoker)")
axes[0, 0].set_ylabel("Highest Total Bill")
axes[0, 0].set_title("Highest Total Bill by Non-Smoking Gender")
for container in axes[0, 0].containers:
    axes[0, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Lowest Total Bill by Non-Smoking Gender ---
sns.barplot(ax=axes[0, 1], x=min_bill_nonsmoker.index, y=min_bill_nonsmoker.values, palette="dark:#1B60D8")
axes[0, 1].set_xlabel("Gender (Non-Smoker)")
axes[0, 1].set_ylabel("Lowest Total Bill")
axes[0, 1].set_title("Lowest Total Bill by Non-Smoking Gender")
for container in axes[0, 1].containers:
    axes[0, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Highest Total Bill by Smoking Gender ---
sns.barplot(ax=axes[1, 0], x=max_bill_smoker.index, y=max_bill_smoker.values, palette="coolwarm")
axes[1, 0].set_xlabel("Gender (Smoker)")
axes[1, 0].set_ylabel("Highest Total Bill")
axes[1, 0].set_title("Highest Total Bill by Smoking Gender")
for container in axes[1, 0].containers:
    axes[1, 0].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# --- Lowest Total Bill by Smoking Gender ---
sns.barplot(ax=axes[1, 1], x=min_bill_smoker.index, y=min_bill_smoker.values, palette="dark:#1B60D8")
axes[1, 1].set_xlabel("Gender (Smoker)")
axes[1, 1].set_ylabel("Lowest Total Bill")
axes[1, 1].set_title("Lowest Total Bill by Smoking Gender")
for container in axes[1, 1].containers:
    axes[1, 1].bar_label(container, fmt="%.2f", fontsize=12, fontweight='bold', color='black', padding=3)

# Add text below each graph
labels = [
    f"Highest Total Bills (Non-Smoker):\n{max_bill_nonsmoker.to_string()}",
    f"Lowest Total Bills (Non-Smoker):\n{min_bill_nonsmoker.to_string()}",
    f"Highest Total Bills (Smoker):\n{max_bill_smoker.to_string()}",
    f"Lowest Total Bills (Smoker):\n{min_bill_smoker.to_string()}"
]

for i, ax in enumerate(axes.flat):
    ax.text(0.5, -0.25, labels[i], fontsize=10, ha="center", va="top", transform=ax.transAxes, 
            bbox=dict(facecolor="lightgray", edgecolor="black", boxstyle="round,pad=0.3"))

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion:-<br>
#     `1.`The resturant Got most profit in the day of `Saturday` following by `Sunday` then `Thursday`<br>
#     `2.`The most profit making Customers are `Non-Smoker`<br>
#     `3.`Between Lunch time and Dinner time The most profit is coming from `Dinner` time<br>
#     `4.`Most Bill and best tips has been made from `Male` customers<br>
#     `5.`In the `Weeakend` most customers are coming for mainly `Dinner` most of them are `Non-Smoker` and `Male`<br>
#     `6.`The hotel is getting profit of `Lunch` in `Thursday`<br>
#     `7.`The highest `tip is 10` when the `total_bill is 50-60`<br>
#     `8.`The most total_bill that has been made lies between `10 to 20`<br>
#     `9.`Nearly `37.5%` people of both gender are `Smoker`<br>
#     `10.`Most of the `Smokers` are coming `Saturday` followed by `Sunday` and `Thursday`<br>
#     `11.`Most of the `Non-Smokers` are coming `Sunurday` followed by `Saturday` and `Thursday`<br>
#     `12.`Most of the Males are coming `Saturday` foloowed by `Sunday` then `Thursday` and `Friday`<br>
#     `13.`Most of the Females are coming `Thursday` foloowed by `Saturday` then `Sunday` and `Friday`<br>
#     `14.`The highest total_bill is made in the day of `Saturday` followed by `Sunday` by the `Male` `Non-Smokers`<br>
#     `15.`The highest tip is made in the day of `Saturday` followed by `Sunday` by the `Male` `Non-Smokers`<br>
#     `16.`The highest tip made by `male is 10` and by `female is 6.5`<br>
#     `17.`The lowest tip made by `male is 1` and by `female is 1`<br>
#     `18.`The highest tip made by `Smoker is 10` and by `Non-Smoker is 9`<br>
#     `19.`The lowest tip made by `Smoker is 1` and by `Non-Smoker is 1`<br>
#     `20.`The highest total_bill made by `Male-Smoker is 50.81` and by `Female-Smoker is 44.33`<br>
#     `21.`The highest total_bill made by `Male-Non-Smoker is 48.33` and by `Female-Non-Smoker is 35.83`<br>
#     `22.`The lowest total_bill made by `Male-Smoker is 7.25` and by `Female-Smoker is 3.07`<br>
#     `23.`The lowest total_bill made by `Male-Non-Smoker is 7.51` and by `Female-Non-Smoker is 7.25`<br>
#     `24.`The highest tip by `Male-Smoker is 10` and `Female-Smoker is 6.5`<br>
#     `25.`The highest tip by `Male-Non-Smoker is 9` and `Female-Non-Smoker is 5.2`<br>
#     `26.`The lowest tip by `Male-Smoker is 1` and `Female-Smoker is 1`<br>
#     `27.`The lowest tip by `Male-Non-Smoker is 1.25` and by `Female-Non-Smoker is 1`<br>
#     `28.`The highest total_bill made by `Male is 50.81` and by `Female is 44.30`<br>
#     `29.`The lowest total_bill made by `Male is 7.25` and by `Female is 3.07`<br>

# %%
# Highest tip made by male
# highest tip made by female
